# %% [markdown]
# #### Output range with increment of 5
# Max Score: 2 | Difficulty: Not Specified
#
# Write a program whose input is two integers. Output the first integer and subsequent
# increments of 5 as long as the value is less than or equal to the second integer.
#
# Ex: If the input is:
#
# -15
# 10
#
#
# the output is:
#
# -15 -10 -5 0 5 10
# Ex: If the second integer is less than the first as in:
#
# 20
# 5
# the output is:
# Second integer can't be less than the first.

# %%
a = int(input("Enter first integer: "))
b = int(input("Enter second integer: "))

if a > b:
    print("Second integer cant be smaller than first integer.")
else:
    print(a, end=" ")
    while a < b:
        a += 5
        print(a, end=" ")
# Out:
# -15 -10 -5 0 5 10
