# %% [markdown]
# #### Print string in reverse
# Max Score: 10 | Difficulty: medium
#
# Write a program that takes in a line of text as input, and outputs that line of text in reverse. The program repeats, ending when the user enters "Done", "done", or "d" for the line of text.
#
# Ex: If the input is:
#
# Hello there
# Hey
# done
#
# then the output is:
#
# ereht olleH
# yeH

# %%
text = input("Enter a text: ")
while text not in ["Done", "done", "DONE", "d"]:

    text2 = text[::-1]  # Reverse the text
    print("Reversed text:", text2)
    
    text = input("Enter a text: ")
    
print(text, "is the end of the program.")
# Out:
# Reversed text: rwqrwq fdnjsjnolleh
# done is the end of the program.

# %%
text  =input("Enter a text: ")
while text != "Done" and text != "done" and text != "DONE" and text != "d":
    text2 = text[::-1] # Reverse the text and append to text2
    print("Reversed text:", text2)
    text = input("Enter a text: ")
    
print(text)
# Out:
# Reversed text: dfjwefdjoa
# d

# %%
range(5)
# Out:
# range(0, 5)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
