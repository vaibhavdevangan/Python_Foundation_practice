# %% [markdown]
# Count input length without spaces, periods, exclamation points, or commas
# Max Score: 10 | Difficulty: medium
#
# Given a line of text as input, output the number of characters excluding spaces, periods, exclamation points, or commas.
#
# Ex: If the input is:
#
# Listen, Mr. Jones, calm down.
#
# the output is:
#
# 21
# Note: Account for all characters that aren't spaces, periods, exclamation points, or commas (Ex: "r", "2", "?").

# %%
text = input("Enter a text: ")
counter = 0
for char in text:
    if char.isalpha():
        counter += 1
print("Number of alphabetic characters:", counter)
# Out:
# Number of alphabetic characters: 21
