# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# ...
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    -------------------- ------------------- 11.8/22.9 MB 56.5 MB/s eta 0:00:01
#    -------------------------------------- - 22.0/22.9 MB 51.6 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 50.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ----------------------- ---------------- 3.7/6.3 MB 18.1 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 9.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [shapely]
# ...

# %%
pip install  rasterio shapely pyproj fiona
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/25.7 MB ? eta -:--:--
#    -------- ------------------------------- 5.2/25.7 MB 29.0 MB/s eta 0:00:01
#    ------------------- -------------------- 12.3/25.7 MB 32.2 MB/s eta 0:00:01
#    -------------------------------- ------- 21.0/25.7 MB 34.9 MB/s eta 0:00:01
#    ---------------------------------------- 25.7/25.7 MB 34.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    ----------- ---------------------------- 7.1/24.5 MB 36.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 10.5/24.5 MB 26.1 MB/s eta 0:00:01
#    ------------------- -------------------- 12.1/24.5 MB 18.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 13.6/24.5 MB 15.8 MB/s eta 0:00:01
#    ------------------------ --------------- 15.2/24.5 MB 14.3 MB/s eta 0:00:01
#    --------------------------- ------------ 17.0/24.5 MB 13.3 MB/s eta 0:00:01
# ...

# %%
sudo apt install -y gdal-bin libgdal-dev
# Out:
#   Cell In[4], line 1
#     sudo apt install -y gdal-bin libgdal-dev
#          ^
# SyntaxError: invalid syntax

# %%
from osgeo import gdal

# %%
pip install rtree pysal osmnx cartopy geopy
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 28.0 MB/s  0:00:00m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 29.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 33.9 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 27.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 29.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 40.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 39.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 45.0 MB/s  0:00:00
# ...

# %%
pip install --upgrade pip setuptools wheel
# Out:
# ...
#   Using cached setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# ...
# Using cached setuptools-82.0.0-py3-none-any.whl (1.0 MB)
# Using cached wheel-0.46.3-py3-none-any.whl (30 kB)
# ...
#   WARNING: The script wheel is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0━━━━━━━━━━━━━━━━━━ 1/2 [setuptools]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [setuptools]2 [setuptools]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas rasterio shapely pyproj fiona rtree pysal osmnx cartopy geopy rasterstats geoplot folium dash plotly 2>&1 | tail -100
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing libraries

import numpy as np
import pandas as pd
import geopandas as gpd
import scipy
import shapely
import matplotlib.pyplot as plt
import pysal
import bokeh
import cartopy
import statsmodels
import sklearn
import geoplot
import osmnx
import folium
import dash
import rasterio
import rasterstats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 10
#       8 import matplotlib.pyplot as plt
#       9 import pysal
# ---> 10 import bokeh
#      11 import cartopy
#      12 import statsmodels
#
# ModuleNotFoundError: No module named 'bokeh'

# %%
pip install bokeh matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 17.8 MB/s  0:00:00 eta 0:00:01
# ...
#   WARNING: The script bokeh is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels cartopy pysal
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------- ----- 9.4/11.0 MB 53.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 49.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------- ----------------------- 1.0/2.5 MB 49.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 7.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/882.2 kB ? eta -:--:--
#    ---------------------------------------- 882.2/882.2 kB ?  0:00:00
# ...

# %%
pip install pycrs
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for pycrs: filename=pycrs-1.0.2-py3-none-any.whl size=32817 sha256=e869b1e091878a62a0f51769ac0f3bc4817be5fddac9f459e29e16b2102d6be5
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\5f\ad\a3\183ed754d7698fc15a2eb153705e05d05a0d97f3331293ce48
# Successfully built pycrs
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing libraries
# importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import sklearn

import geopandas as gpd
import shapely
import pysal
import bokeh
import cartopy
import statsmodels
import geoplot
import osmnx
import folium
import dash
import rasterio
import rasterstats
